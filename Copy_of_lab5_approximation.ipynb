# %% [markdown]
# <a href="https://colab.research.google.com/github/tjs226/CSE337-Lab_5/blob/main/Copy_of_lab5_approximation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 5: Value-Function Approximation
#
#
# ## Exercise 1 SGD
# Many real-world processes can be modeled as nonlinear relationships, and SGD is a standard tool to fit those models from data.
#
# **Example: Predicting energy consumption in a building**
# - Energy usage depends on **temperature**, **time of day**, and **occupancy**.
# - If you plot the data, the relationship might not be linear — it curves.
# - A simple way to approximate this nonlinear relation is to fit a **polynomial function** of temperature (or time).
#
# Now, imagine you’re collecting data continuously:
# - You get one data point (temperature, usage) at a time.
# - Instead of waiting to collect all data and computing a full batch update, you update your model incrementally with **SGD**.
# - This makes your learning **online, adaptive, and scalable** — just like in reinforcement learning.
#
# ---
#
# In this exercise, approximating a cubic polynomial is a simplified version of **predicting a nonlinear real-world phenomenon**.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data based on a cubic polynomial with Gaussian noise
np.random.seed(42)  # for reproducibility
n_samples = 100
x = np.linspace(-5, 5, n_samples)
# Define the true cubic polynomial function
def true_function(x):
  return 0.1 * x**3 - 0.5 * x**2 + 2 * x + 5

y_true = true_function(x)
noise = np.random.normal(0, 2, n_samples)  # Gaussian noise with mean 0 and std dev 2
y = y_true + noise

# Plot the generated data
plt.scatter(x, y, label='Generated Data')
plt.plot(x, y_true, color='red', label='True Function')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Generated Data with Cubic Polynomial and Gaussian Noise')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Based on the given a dataset of input–output pairs `(x, y)` where the underlying relationship is approximately polynomial.
#
# a. Use a **linear model with polynomial features**: Write a function that takes an input `x` and a weight vector `w`, and return the predicted value y_hat.
#
#    - y_hat(x; w) = w0 + w1 * x + w2 * x^2 + w3 * x^3
#
#    where w0, w1, w2, w3 are the parameters to be learned.
#
# b. **Loss function (Mean Squared Error)**:
#    Write a function that computes the loss for one training point `(x, y)`:
#
#      - Formula: `loss = 0.5 * (y - y_hat)**2`
#
# c. **SGD update**:   Derive the gradient of the loss with respect to each parameter (w0, w1, w2, w3).
#    - Write a function:
#
#      ```python
#      def sgd_update(x, y, w, alpha):
#          """
#          Perform one SGD update for a single training example.
#          Input:
#              x (float) - input value
#              y (float) - true output
#              w (np.array) - current weights
#              alpha (float) - learning rate
#          Output:
#              w (np.array) - updated weights
#          """
#          # TODO: compute prediction, gradient, and update weights
#          return w
#      ```
# d. **Training loop**:
#    - Loop over the dataset.
#    - At each step, update the weights using `sgd_update`.
#    - Track the training loss after each iteration.
#
# e. **Comparison with different learning rates**
#    - Train your model using at least three different learning rates, for example:
#      - alpha = 0.001
#      - alpha = 0.01
#      - alpha = 0.1
#    - Plot training loss vs iteration for each learning rate.
#    - Plot the final fitted polynomial curves for each learning rate on the same graph with the true dataset.
#
# ---
#
# ### Deliverables
# - Code for `predict`, `mse_loss`, and `sgd_update`.
# - Training loop that runs with multiple learning rates.
# - Plot of training loss vs iteration for each learning rate.
# - Plot of the fitted polynomial vs dataset for each learning rate.
# - A short discussion:
#   - How does the learning rate affect convergence speed and stability?
#   - Which learning rate gives the best balance between speed and accuracy?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data based on a cubic polynomial with Gaussian noise (like above)
np.random.seed(42)
n_samples = 100
x = np.linspace(-5, 5, n_samples)

# Same as above
def true_function(x):
    return 0.1 * x**3 - 0.5 * x**2 + 2 * x + 5

y_true = true_function(x)
noise = np.random.normal(0, 2, n_samples)
y = y_true + noise


# Predict y_hat = w0 + w1*x + w2*x^2 + w3*x^3
def predict(x, w):
    return w[0] + w[1]*x + w[2]*(x**2) + w[3]*(x**3)


# Loss function (Mean Squared Error) = 0.5 * (y - y_hat)**2`
def mse_loss(x, y, w):
    y_hat = predict(x, w)
    return 0.5 * (y - y_hat)**2

# compute prediction, gradient, and update weights
def sgd_update(x, y, w, alpha):

    y_hat = predict(x, w)
    # update the vector
    w[0] =  w[0] - alpha * ((y_hat - y) * 1)
    w[1] =  w[1] - alpha * ((y_hat - y) * x)
    w[2] = w[2] - alpha * ((y_hat - y) * (x**2))
    w[3] =  w[3] - alpha * ((y_hat - y) * (x**3))

    return w

# Function to Train the Model
def train_sgd(x, y, alpha, n_epoch):
    w = np.zeros(4)
    losses = [] # keep track of loss for each iteration
    for epoch in range(n_epoch): # epoch is a full iteration of the model
        for i in range(len(x)):
            w = sgd_update(x[i], y[i], w, alpha)
            losses.append(mse_loss(x[i], y[i], w))
    return w, losses


# Train and Plot
learning_rates = [0.0001, 0.00001, 0.000001]
all_weights = []
all_losses = []

# Train model
for alpha in learning_rates:
    w, losses = train_sgd(x, y, alpha, 100) # 100 iterations
    all_weights.append(w)
    all_losses.append(losses)

# Plot 3 separate loss curves
for i, alpha in enumerate(learning_rates):
    plt.figure(figsize=(10, 4))
    plt.plot(all_losses[i])
    plt.xlabel("Iteration")
    plt.ylabel("Training Loss")
    plt.title(f"Training Loss vs Iteration (alpha={alpha})")
    plt.grid(True)
    plt.show()

# Plot true function + all fitted polynomials
plt.figure(figsize=(12,6))
plt.scatter(x, y, color="gray", label="Data", alpha=0.5)
plt.plot(x, y_true, linewidth=2, label="True function", color="blue")

colors = ["red", "green", "purple"]
for i, alpha in enumerate(learning_rates):
    plt.plot(
        x,
        predict(x, all_weights[i]),
        linestyle="--",
        linewidth=2,
        label=f"Fitted (alpha={alpha})",
        color=colors[i]
    )

plt.xlabel("x")
plt.ylabel("y")
plt.title("True Function vs Fitted Polynomials")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# As far as the learning rate size, the larger the learning rate in the case of (0.0001, 0.00001, 0.000001) 0.0001 performed the best.  In this case the larger rate appears to converge a tad faster.  The smaller learning rates did no aproximate the function as well and apeared to overshoot when the inflextion of the target function chnaged

# %% [markdown]
# *Exercise 2: 1000-State Random Walk with Semi-Gradient TD(0)\*
#
# We will study the 1,000-state Random Walk a classic reinforcement learning benchmark from Sutton & Barto.
#
# - The environment has states numbered **1 to 1000**.
# - There are two **terminal states**:
#   - State `0` on the left (reward = 0)
#   - State `1001` on the right (reward = 1)
# - Each episode starts in the **middle** at state `500`.
# - At each step, the agent moves **left or right with equal probability (0.5 each)**.
# - The episode ends when the agent reaches either terminal.
# - Discount factor: **γ = 1.0** (episodic task).
#
#
# ### Function Approximation
# Instead of storing a separate value for each state, approximate the value function with a **linear function of the state index**: V_hat(s; w0, w1) = w0 + w1 * s
#
#
#
# ---
#
# ## Instructions
# 1. **Implement the environment**:
#    - You may **use AI tools such as ChatGPT** to generate the environment code (states, transitions, rewards).
#    - Make sure you understand how the environment works.
#
# 2. **Implement the TD(0) update manually**:
#    - Do **not** use AI for this part.
#    - You must write the gradient update equations yourself using the formulas above.
#
# 3. **Train your agent**:
#    - Run several episodes (e.g., 1000 episodes).
#    - Experiment with different step sizes (`alpha`).
#
# 4. **Evaluate**:
#    - Plot the **true value function** `V*(s) = s/1001`.
#    - Plot your **learned approximation line** after training.
#    - Discuss whether the line captures the overall trend of the true values.
#
# ---
#
#
# ## Guidelines on Using AI Tools
# - You are encouraged to use AI tools (e.g., ChatGPT, Gemini, Copilot) to **generate helper code**, such as:
#   - Building the random walk environment (`reset`, `step`).
#   - Implementing the feature map φ(s).
#   - Plotting results.
# - However, **do not use AI tools to generate the TD(0) update equation**.
#   - Deriving and implementing the update is the key learning objective of this exercise.
#   - If we find code that uses an AI-generated update without understanding, the score will be zero.
#
#
# ## Deliverables
# - Python code for the environment and the TD(0) algorithm.
# - Plot the **true value function**: For state `s`, the probability of reaching the right terminal is:
#   `V*(s) = s / 1001`
# - Plot comparing the true value function and the approximated line.
# - A short discussion:
#   - How does the approximation behave for small vs large states?
#   - How does the learning rate affect convergence?
#
# ---
#
# ## Hints
# - Normalize states to `[0,1]` before using them in the line approximation to avoid very large values for w1.
# - Start with small step sizes (e.g., 0.001–0.01).
# - The approximation will not be perfect (a line cannot match the true curve), but should capture the increasing trend.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Global Params
n_states = 1000                   # 1000 states
start_state = 500                 # Starting Point (middle)
terminal_left = 0                 # left side terminal point
terminal_right = n_states + 1     # right side terminal point
gamma = 1.0                       # discount factor
alpha = 0.01                     # learning rate
episodes = 100                  # episodes
w = np.zeros(2)                   # weights [w0, w1]
rng = np.random.default_rng(42)


# V_hat(s) = w0 + w1 * s/1001 (given), s is the current position
# note: dividing by 1001 normilizes the positions
# this is the linear function of the state index
def V_hat(s, w):
    return w[0] + w[1] * (s / 1001.0)


ep_lengths = []

# Train
for ep in range(episodes):
    state = start_state # reset the state
    done = False
    steps = 0

    while not done:
        # Move Randomly (50/50% probabilty)
        move = rng.choice([-1, 1])
        next_state = state + move # update the state

        # Find what the reward is
        if next_state == terminal_right:
            reward = 1.0
            done = True
        elif next_state == terminal_left:
            reward = 0.0
            done = True
        else:
            reward = 0.0 # no reward....have not reached a terminal state

        # TD(0) update
        v_s = V_hat(state, w) # predict value of current state

        if done: # done = we have reached the terminal state

            if next_state == terminal_left: # did we end on left
                v_next = 0.0
            elif next_state == terminal_right: # did we end on right
                v_next = 1.0
        else:
            v_next = V_hat(next_state, w) # predicted value of next state

        #compute TD Error
        delta = reward + gamma * v_next - v_s

        #update the weights
        w[0] += alpha * delta * 1
        w[1] += alpha * delta * (state / 1001.0)

        state = next_state
        steps += 1

    ep_lengths.append(steps)
    print(f"Episode {ep+1}/{episodes}, Steps={steps}, w={w}") # Print Episode Info (Comment Out if you want )


# plot true values VS the ones learned
S = np.arange(1, n_states + 1)
V_true = S / 1001.0
V_learned = V_hat(S, w)

plt.figure(figsize=(10,5))
plt.plot(S, V_true, label="True Value V*(s)", linewidth=2)
plt.plot(S, V_learned, '--', label=f"Learned Approx V̂(s), w={np.round(w,3)}")
plt.xlabel("State s")
plt.ylabel("Value")
plt.title("1000-State Random Walk: True vs Learned Value Function")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Episode 1/100, Steps=187491, w=[0.02       0.01998002]
# Episode 2/100, Steps=121856, w=[0.01970128 0.01994277]
# Episode 3/100, Steps=508055, w=[0.03940308 0.03954954]
# Episode 4/100, Steps=98824, w=[0.03881363 0.03948035]
# Episode 5/100, Steps=437576, w=[0.03823042 0.03934461]
# Episode 6/100, Steps=286495, w=[0.05764849 0.05863804]
# Episode 7/100, Steps=320408, w=[0.05678227 0.05847061]
# Episode 8/100, Steps=136733, w=[0.07591776 0.07747419]
# Episode 9/100, Steps=128156, w=[0.07477578 0.07732734]
# Episode 10/100, Steps=83021, w=[0.09363566 0.0960398 ]
# Episode 11/100, Steps=475839, w=[0.11221201 0.11425037]
# Episode 12/100, Steps=34071, w=[0.13051017 0.13236818]
# Episode 13/100, Steps=308200, w=[0.12855103 0.13199848]
# Episode 14/100, Steps=471638, w=[0.12661331 0.13152194]
# Episode 15/100, Steps=540695, w=[0.14467987 0.14905219]
# Episode 16/100, Steps=685878, w=[0.1424966  0.14835501]
# Episode 17/100, Steps=140517, w=[0.16031887 0.16587032]
# Episode 18/100, Steps=111285, w=[0.17787404 0.18310894]
# Episode 19/100, Steps=134206, w=[0.17519055 0.18275624]
# Episode 20/100, Steps=45326, w=[0.17253564 0.18248534]
# Episode 21/100, Steps=77541, w=[0.18988433 0.19951833]
# Episode 22/100, Steps=46696, w=[0.18699966 0.19922121]
# Episode 23/100, Steps=313552, w=[0.18414531 0.19865907]
# Episode 24/100, Steps=348096, w=[0.18132227 0.19806419]
# Episode 25/100, Steps=93202, w=[0.17853041 0.19772338]
# Episode 26/100, Steps=113937, w=[0.19574184 0.2145585 ]
# Episode 27/100, Steps=214140, w=[0.19272428 0.21405981]
# Episode 28/100, Steps=125908, w=[0.18973936 0.21365655]
# Episode 29/100, Steps=152822, w=[0.18678628 0.21322541]
# Episode 30/100, Steps=214293, w=[0.20383651 0.22976487]
# Episode 31/100, Steps=388056, w=[0.20066286 0.22903174]
# Episode 32/100, Steps=250319, w=[0.21749413 0.24527512]
# Episode 33/100, Steps=248891, w=[0.23407467 0.26122891]
# Episode 34/100, Steps=1246274, w=[0.23044319 0.25927916]
# Episode 35/100, Steps=88862, w=[0.22685765 0.25883865]
# Episode 36/100, Steps=224963, w=[0.24327573 0.27462724]
# Episode 37/100, Steps=737524, w=[0.23948603 0.27327317]
# Episode 38/100, Steps=491387, w=[0.25570463 0.28846757]
# Episode 39/100, Steps=139698, w=[0.25172225 0.28790445]
# Episode 40/100, Steps=296446, w=[0.24778249 0.28711689]
# Episode 41/100, Steps=214403, w=[0.26384783 0.30250098]
# Episode 42/100, Steps=371393, w=[0.27967449 0.31737486]
# Episode 43/100, Steps=225945, w=[0.29526739 0.33219845]
# Episode 44/100, Steps=67427, w=[0.3106291  0.34701839]
# Episode 45/100, Steps=111353, w=[0.32576201 0.36151009]
# Episode 46/100, Steps=140970, w=[0.32071815 0.36080197]
# Episode 47/100, Steps=341776, w=[0.31572824 0.35973339]
# Episode 48/100, Steps=105850, w=[0.3107935  0.35909177]
# Episode 49/100, Steps=32566, w=[0.30591127 0.35858268]
# Episode 50/100, Steps=303354, w=[0.30108039 0.3575901 ]
# Episode 51/100, Steps=577076, w=[0.29630272 0.3561129 ]
# Episode 52/100, Steps=400338, w=[0.29158013 0.35495515]
# Episode 53/100, Steps=358252, w=[0.28691049 0.35387486]
# Episode 54/100, Steps=70425, w=[0.30224578 0.36862885]
# Episode 55/100, Steps=139502, w=[0.29740191 0.36790967]
# Episode 56/100, Steps=421261, w=[0.31256117 0.38182377]
# Episode 57/100, Steps=108581, w=[0.32749814 0.39606276]
# Episode 58/100, Steps=830732, w=[0.32226621 0.3939255 ]
# Episode 59/100, Steps=279563, w=[0.33704478 0.40765026]
# Episode 60/100, Steps=703009, w=[0.35160606 0.42026369]
# Episode 61/100, Steps=110050, w=[0.34601346 0.41950556]
# Episode 62/100, Steps=277371, w=[0.36042477 0.43279961]
# Episode 63/100, Steps=100334, w=[0.35468204 0.4320397 ]
# Episode 64/100, Steps=71043, w=[0.368943   0.44559403]
# Episode 65/100, Steps=41794, w=[0.36305187 0.44494194]
# Episode 66/100, Steps=121605, w=[0.37716367 0.45821466]
# Episode 67/100, Steps=116800, w=[0.37112798 0.45737276]
# Episode 68/100, Steps=273496, w=[0.36515681 0.45617444]
# Episode 69/100, Steps=28312, w=[0.35925126 0.45553765]
# Episode 70/100, Steps=723763, w=[0.37334752 0.46741138]
# Episode 71/100, Steps=130972, w=[0.36730455 0.46651946]
# Episode 72/100, Steps=333121, w=[0.38126441 0.47911079]
# Episode 73/100, Steps=207369, w=[0.39502075 0.49176034]
# Episode 74/100, Steps=53758, w=[0.38864074 0.4910115 ]
# Episode 75/100, Steps=401804, w=[0.38232823 0.48940976]
# Episode 76/100, Steps=250152, w=[0.37608676 0.48818432]
# Episode 77/100, Steps=238295, w=[0.38984885 0.50074394]
# Episode 78/100, Steps=105362, w=[0.38347617 0.49985248]
# Episode 79/100, Steps=328889, w=[0.39710519 0.51202652]
# Episode 80/100, Steps=257750, w=[0.3906042  0.51072529]
# Episode 81/100, Steps=229078, w=[0.38417464 0.50950135]
# Episode 82/100, Steps=246541, w=[0.39774768 0.52180061]
# Episode 83/100, Steps=50466, w=[0.39119197 0.52101465]
# Episode 84/100, Steps=63308, w=[0.38470569 0.52019667]
# Episode 85/100, Steps=178642, w=[0.37828832 0.51908087]
# Episode 86/100, Steps=481682, w=[0.37194064 0.51718331]
# Episode 87/100, Steps=95829, w=[0.38559699 0.52993352]
# Episode 88/100, Steps=344381, w=[0.39905219 0.54180551]
# Episode 89/100, Steps=342497, w=[0.41231259 0.55345288]
# Episode 90/100, Steps=360667, w=[0.42538129 0.56482517]
# Episode 91/100, Steps=267461, w=[0.43826157 0.57623576]
# Episode 92/100, Steps=74877, w=[0.45095506 0.58798203]
# Episode 93/100, Steps=96805, w=[0.46346203 0.59945854]
# Episode 94/100, Steps=475193, w=[0.47578586 0.60960728]
# Episode 95/100, Steps=113919, w=[0.48793479 0.62063712]
# Episode 96/100, Steps=158471, w=[0.4999063  0.63133146]
# Episode 97/100, Steps=81643, w=[0.51170379 0.64207208]
# Episode 98/100, Steps=101095, w=[0.52332882 0.65255949]
# Episode 99/100, Steps=99124, w=[0.51487121 0.6514182 ]
# Episode 100/100, Steps=93079, w=[0.52641714 0.66183658]

# %% [markdown]
# As far as the states go, for large states the approximation predicts a higher value (meaning close to the right terminal state)VS the smaller states (small value meaning far from the right terminal state). For a smaller learning rate the convergance is slower vs a larger learning right where the congergence is faster

# %% [markdown]
# # Exercise 3: Solving MountainCar with Tile Coding and SARSA
#
# ## Problem Description
# In this exercise, you will solve the **MountainCar-v0** environment from Gym using **tile coding** for function approximation and the **SARSA algorithm** for learning.
#
# The **Mountain Car problem**:
# - A car is stuck in a valley and is too weak to drive straight up to the goal.
# - It must build momentum by going back and forth until it can reach the goal at `position >= 0.5`.
# - **State space**: continuous (position, velocity).
# - **Actions**: {0: push left, 1: no push, 2: push right}.
# - **Reward**: -1 per step until the goal is reached.
# - **Episode ends**: when the car reaches the goal or after 200 steps.
#
# ---
#
# ## Step 1: Environment and Random Policy (with AI help)
# - Use an **AI tool (e.g., ChatGPT)** to generate starter code for:
#   - Creating the Gym environment (`MountainCar-v0`).
#   - Running a **random policy** (actions chosen randomly).
# - Run this code to confirm you can interact with the environment and see episode returns.
# - This will serve as a **baseline**.
# - **Important**: Do not use AI to implement the learning algorithm.
#
# ---
#
# ## Step 2: SARSA Algorithm with Function Approximation
# Implement **SARSA (on-policy TD control)** with the following steps:
#
# For each episode:
# 1. Initialize state `s`.
# 2. Choose action `a` using **ε-greedy** based on Q(s,a).
# 3. For each step:
#    - Take action `a`, observe `(s_next, r, done)`.
#    - Choose next action `a_next` using ε-greedy from `s_next`.
#    - Compute TD target:
#      ```
#      target = r + gamma * Q(s_next, a_next)
#      ```
#      (if `s_next` is terminal, then target = r).
#    - Compute TD error:
#      ```
#      delta = target - Q(s,a)
#      ```
#    - Update weights:
#      ```
#      w <- w + alpha * delta * x(s,a)
#      ```
#    - Update `s = s_next`, `a = a_next`.
# 4. End episode when the goal is reached or step limit is hit.
#
# ---
#
# ## Step 3: Experiments
# - Train the agent for 500–1000 episodes.
# - Plot **episode returns (sum of rewards)** vs episodes.
# - Compare with the random policy baseline:
#   - Does SARSA learn to consistently reach the goal?
#   - How many steps does it typically take?
#
# ---
#
# ## Deliverables
# - Python code for tile coding and SARSA.
# - Plot of returns vs episodes.
# - Plot the Value function
# - Short discussion (1–2 paragraphs):
#   - Effect of tile coding parameters (number of tilings, resolution).

# %%
# You can use the following code for tiling

import numpy as np


class TileCoderXY:
    """
    A TileCoder for function approximation that applies tile coding on the x and y coordinates
    of a 3D state. Instead of providing tile widths, the user provides the number of tiles per
    dimension. The tile widths are computed based on the state bounds and the number of tiles.
    The z coordinate is not used.
    """

    def __init__(self, num_tilings, tiles_per_dim, state_low, state_high):
        """
        Initialize the TileCoderXY.

        Parameters:
            num_tilings (int): Number of overlapping tilings.
            tiles_per_dim (array-like of 2 ints): Number of tiles along the x and y dimensions.
            state_low (array-like of 2 floats): Lower bounds for the x and y dimensions.
            state_high (array-like of 2 floats): Upper bounds for the x and y dimensions.
        """
        self.num_tilings = num_tilings
        self.tiles_per_dim = np.array(tiles_per_dim, dtype=int)
        self.state_low = np.array(state_low, dtype=float)
        self.state_high = np.array(state_high, dtype=float)

        # Compute the tile width for each dimension.
        # We assume that the grid spans exactly from state_low to state_high.
        # When there are N tiles, there are N-1 intervals between the boundaries.
        self.tile_width = (self.state_high - self.state_low) / (self.tiles_per_dim - 1)

        # Precompute an offset for each tiling to create overlapping grids.
        # self.offsets = [(i / self.num_tilings) * self.tile_width for i in range(self.num_tilings)]
        # self.offsets = self.compute_8_offsets()
        # self.offsets = np.stack(self._compute_offsets(), axis=0)  # shape: (num_tilings, dims)
        # Precompute offsets for each tiling.
        # For tiling i:
        #   offset_x = (((i + 0) % num_tilings) / num_tilings) * tile_width[0]
        #   offset_y = (((i + 1) % num_tilings) / num_tilings) * tile_width[1]
        offsets = np.empty((self.num_tilings, 2))
        for i in range(self.num_tilings):
            offsets[i, 0] = (((i + 0) % self.num_tilings) / self.num_tilings) * self.tile_width[0]
            offsets[i, 1] = (((i + 1) % self.num_tilings) / self.num_tilings) * self.tile_width[1]
        self.offsets = offsets


        # Precompute multiplier for flattening a 2D index.
        # For grid shape (N, M), flat index = x_index * M + y_index.
        self.multiplier = self.tiles_per_dim[1]

        # Initialize a weight vector for each tiling.
        num_tiles = np.prod(self.tiles_per_dim)
        self.weights = [np.zeros(num_tiles) for _ in range(self.num_tilings)]

    def save(self, file_name):
        np.savez(file_name + ".npz", weights=self.weights)

    def load(self, file_name):
        self.weights = np.load(file_name+".npz")["weights"]


    def compute_8_offsets(self):
        """
        Compute a list of offsets using a combination of cardinal and diagonal directions.
        The offsets include:
          - Center: [0, 0]
          - Cardinal: right, left, up, down (half-tile shifts)
          - Diagonal: up-right, up-left, down-right, down-left (half-tile shifts)

        If the number of tilings exceeds the number of unique offsets (9), the list is repeated.

        Returns:
            List of 2-element numpy arrays representing the offset for each tiling.
        """
        half_tile = self.tile_width / 8.0
        base_offsets = [
            np.array([0.0, 0.0]),  # Center (no shift)
            np.array([half_tile[0], 0.0]),  # Right
            np.array([-half_tile[0], 0.0]),  # Left
            np.array([0.0, half_tile[1]]),  # Up
            np.array([0.0, -half_tile[1]]),  # Down
            np.array([half_tile[0], half_tile[1]]),  # Up-right
            np.array([-half_tile[0], half_tile[1]]),  # Up-left
            np.array([half_tile[0], -half_tile[1]]),  # Down-right
            np.array([-half_tile[0], -half_tile[1]])  # Down-left
        ]
        offsets = []
        for i in range(self.num_tilings):
            offsets.append(base_offsets[i % len(base_offsets)])
        return offsets

    def get_tile_indices(self, state):
        """
        Compute the active tile indices for all tilings given a 2D state.

        Parameters:
            state (array-like of length 2): The input state [x, y].

        Returns:
            List of tuples (tiling_index, flat_tile_index) for each tiling.
        """
        state = np.array(state, dtype=float)  # shape: (2,)
        # Compute shifted states for all tilings in one vectorized operation.
        # Shape of shifted: (num_tilings, 2)
        shifted = (state - self.state_low) + self.offsets

        # Compute tile coordinates (integer indices) for each tiling.
        # Division is broadcasted over the offsets.
        tile_coords = (shifted / self.tile_width).astype(int)  # shape: (num_tilings, 2)

        # Clip to ensure indices are within bounds.
        tile_coords[:, 0] = np.clip(tile_coords[:, 0], 0, self.tiles_per_dim[0] - 1)
        tile_coords[:, 1] = np.clip(tile_coords[:, 1], 0, self.tiles_per_dim[1] - 1)

        # Compute flat indices for each tiling.
        # flat_index = x_index * (tiles_per_dim[1]) + y_index
        flat_indices = tile_coords[:, 0] * self.tiles_per_dim[1] + tile_coords[:, 1]

        # Return a list of (tiling_index, flat_index) tuples.
        return list(zip(range(self.num_tilings), flat_indices))


    def predict(self, state):
        """
        Compute the approximated function value for a given 3D state using tile coding on x and y.

        Parameters:
            state (array-like): The input state [x, y, z].

        Returns:
            float: The function approximation (sum of weights for the active tiles).
        """
        active_tiles = self.get_tile_indices(state)
        return sum(self.weights[tiling][idx] for tiling, idx in active_tiles)

    def update(self, state, target, alpha):
        """
        Update the weights given a state and target value.

        Parameters:
            state (array-like): The input state [x, y, z].
            target (float): The target function value.
            alpha (float): The overall learning rate.
        """
        prediction = self.predict(state)
        error = target - prediction
        # Distribute the learning rate equally among all tilings.
        alpha_per_tiling = alpha / self.num_tilings

        active_tiles = self.get_tile_indices(state)
        for tiling, idx in active_tiles:
            self.weights[tiling][idx] += alpha_per_tiling * error

# %%
# Install gymnasium
pip install gymnasium[classic-control] # this is for running in a zsh terminal on my local IMAC, it may not run on co-lab
# Out:
#   File "/tmp/ipython-input-1381582990.py", line 2
#     pip install gymnasium[classic-control]
#         ^
# SyntaxError: invalid syntax

# %%
# Sample Envirment with Random Policy

import gymnasium as gym
import numpy as np
import time

# Make the Envirment
env = gym.make("MountainCar-v0", render_mode="human")  # human mode opens a window

n_episodes = 5      # number of episodes to run
max_steps = 200     # max steps per episode

for episode in range(n_episodes):
    state, info = env.reset()
    total_reward = 0

    for step in range(max_steps):
        # choose a random action {0: left, 1: no push, 2: right}
        action = env.action_space.sample()

        # take the action
        next_state, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

        # update state
        state = next_state

        # slows down the simulation (it was going to fast for me to see)
        #time.sleep(0.01)

        # check if episode finished
        if terminated or truncated:
            break

    print(f"Episode {episode+1}: total reward = {total_reward}")

env.close()
# Out:
# Episode 1: total reward = -200.0
# Episode 2: total reward = -200.0
# Episode 3: total reward = -200.0
# Episode 4: total reward = -200.0
# Episode 5: total reward = -200.0

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import time

# Global Parametors
NUM_TILINGS = 8
TILES_PER_DIM = (8, 8) #also know as resolution
ALPHA = 0.1            # learning rate
GAMMA = 0.99           # discount factor
EPSILON = 0.1
N_EPISODES = 500
MAX_STEPS = 200
RENDER = False          # True to see the environment (when running locally only )


# SARSA
# I choose to make a class for my SARSA Agent like how the tilecoder was given to us
class SARSAAgent:

    #constructor function
    def __init__(self, tilecoder, n_actions, alpha=ALPHA, gamma=GAMMA, epsilon=EPSILON):
        self.tilecoder = tilecoder
        self.n_actions = n_actions
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.weights = [ [w.copy() for w in tilecoder.weights] for _ in range(n_actions) ] # initulize the weight vector

    # Compute Q(S, A) which is aproximated with the tile codeings since we dont have a Q table since its infinate
    def q(self, state, action):
        active_tiles = self.tilecoder.get_tile_indices(state)
        q_value = 0.0  # initialize Q-value )

        # Loop over all active tiles and add their contribution
        for t, idx in active_tiles:
            q_value += self.weights[action][t][idx]
        return q_value

    # Find all Q - values for a given state
    def q_values(self, state):
        q_vals = []  # initialize list to store Q-values

        for a in range(self.n_actions):
            q_val = self.q(state, a)  # compute Q(s,a)
            q_vals.append(q_val)      # add it to the list of already found q values
        return np.array(q_vals)

    # Implementation of the e greedy policy
    def choose_action(self, state):
        if np.random.rand() < self.epsilon: # only do for epsilon percent of the time (exploration)
            return np.random.randint(self.n_actions)
        q_vals = self.q_values(state)
        max_q = np.max(q_vals) # get highest Q value
        candidates = np.where(np.isclose(q_vals, max_q))[0]
        return np.random.choice(candidates)

    # Update Q values
    # target = reward + gamma * Q(next_state, next_action)
    # delta = target - Q(s,a)
    # w <- w + alpha * delta * x(s,a)
    def update(self, state, action, target):
        prediction = self.q(state, action)
        delta = target - prediction # calculate TD Error
        alpha_per_tiling = self.alpha / self.tilecoder.num_tilings
        active_tiles = self.tilecoder.get_tile_indices(state)
        # Update the weights of the found/active tillings taking into account the TD error
        for t, idx in active_tiles:
            self.weights[action][t][idx] += alpha_per_tiling * delta

# Train SARSA and keep track of the returns
def train_sarsa(env, agent, n_episodes=N_EPISODES, max_steps=MAX_STEPS):
    returns = []

    for ep in range(n_episodes):
        state, _ = env.reset()
        action = agent.choose_action(state)
        total_reward = 0

        for step in range(max_steps):
            next_state, reward, terminated, truncated, _ = env.step(action)
            total_reward += reward

            if terminated or truncated:
                target = reward
                agent.update(state, action, target)
                break
            else:
                next_action = agent.choose_action(next_state)
                target = reward + agent.gamma * agent.q(next_state, next_action)
                agent.update(state, action, target)
                state, action = next_state, next_action

        returns.append(total_reward)
        print(f"Episode {ep+1}, return={total_reward}, avg_last50={np.mean(returns[-50:]):.2f}") # print the result of each episode

    return returns

# Create the simulation and run
render_mode = "human" if RENDER else None # human to view simulation locally

env = gym.make("MountainCar-v0", render_mode=render_mode)
state_low = env.observation_space.low
state_high = env.observation_space.high
n_actions = env.action_space.n
  # Create an Instance of the tile coder
tilecoder = TileCoderXY(num_tilings=NUM_TILINGS, tiles_per_dim=TILES_PER_DIM,
                            state_low=state_low, state_high=state_high)
  # Create an Instance of the Sarsa agent (with the tile coder)
agent = SARSAAgent(tilecoder, n_actions)

returns = train_sarsa(env, agent, n_episodes=N_EPISODES)

# Plot returns
plt.figure(figsize=(12,5))
plt.plot(returns, alpha=0.3, label="Episode return")
window = 20
mov_avg = np.convolve(returns, np.ones(window)/window, mode='valid')
plt.plot(np.arange(window-1,N_EPISODES), mov_avg, label=f"{window}-episode moving average", linewidth=2)
plt.xlabel("Episode")
plt.ylabel("Return")
plt.title("SARSA + Tile Coding")
plt.legend()
plt.show()
# Out:
# Episode 1, return=-200.0, avg_last50=-200.00
# Episode 2, return=-200.0, avg_last50=-200.00
# Episode 3, return=-200.0, avg_last50=-200.00
# Episode 4, return=-200.0, avg_last50=-200.00
# Episode 5, return=-200.0, avg_last50=-200.00
# Episode 6, return=-200.0, avg_last50=-200.00
# Episode 7, return=-200.0, avg_last50=-200.00
# Episode 8, return=-200.0, avg_last50=-200.00
# Episode 9, return=-200.0, avg_last50=-200.00
# Episode 10, return=-200.0, avg_last50=-200.00
# Episode 11, return=-200.0, avg_last50=-200.00
# Episode 12, return=-200.0, avg_last50=-200.00
# Episode 13, return=-200.0, avg_last50=-200.00
# Episode 14, return=-200.0, avg_last50=-200.00
# Episode 15, return=-200.0, avg_last50=-200.00
# Episode 16, return=-200.0, avg_last50=-200.00
# Episode 17, return=-200.0, avg_last50=-200.00
# Episode 18, return=-200.0, avg_last50=-200.00
# Episode 19, return=-200.0, avg_last50=-200.00
# Episode 20, return=-200.0, avg_last50=-200.00
# Episode 21, return=-200.0, avg_last50=-200.00
# Episode 22, return=-200.0, avg_last50=-200.00
# Episode 23, return=-200.0, avg_last50=-200.00
# Episode 24, return=-200.0, avg_last50=-200.00
# Episode 25, return=-200.0, avg_last50=-200.00
# Episode 26, return=-200.0, avg_last50=-200.00
# Episode 27, return=-200.0, avg_last50=-200.00
# Episode 28, return=-200.0, avg_last50=-200.00
# Episode 29, return=-200.0, avg_last50=-200.00
# Episode 30, return=-200.0, avg_last50=-200.00
# Episode 31, return=-200.0, avg_last50=-200.00
# Episode 32, return=-200.0, avg_last50=-200.00
# Episode 33, return=-200.0, avg_last50=-200.00
# Episode 34, return=-200.0, avg_last50=-200.00
# Episode 35, return=-200.0, avg_last50=-200.00
# Episode 36, return=-200.0, avg_last50=-200.00
# Episode 37, return=-200.0, avg_last50=-200.00
# Episode 38, return=-200.0, avg_last50=-200.00
# Episode 39, return=-200.0, avg_last50=-200.00
# Episode 40, return=-200.0, avg_last50=-200.00
# Episode 41, return=-200.0, avg_last50=-200.00
# Episode 42, return=-200.0, avg_last50=-200.00
# Episode 43, return=-200.0, avg_last50=-200.00
# Episode 44, return=-200.0, avg_last50=-200.00
# Episode 45, return=-200.0, avg_last50=-200.00
# Episode 46, return=-200.0, avg_last50=-200.00
# Episode 47, return=-200.0, avg_last50=-200.00
# Episode 48, return=-200.0, avg_last50=-200.00
# Episode 49, return=-200.0, avg_last50=-200.00
# Episode 50, return=-200.0, avg_last50=-200.00
# Episode 51, return=-200.0, avg_last50=-200.00
# Episode 52, return=-200.0, avg_last50=-200.00
# Episode 53, return=-200.0, avg_last50=-200.00
# Episode 54, return=-200.0, avg_last50=-200.00
# Episode 55, return=-200.0, avg_last50=-200.00
# Episode 56, return=-200.0, avg_last50=-200.00
# Episode 57, return=-200.0, avg_last50=-200.00
# Episode 58, return=-200.0, avg_last50=-200.00
# Episode 59, return=-200.0, avg_last50=-200.00
# Episode 60, return=-200.0, avg_last50=-200.00
# Episode 61, return=-200.0, avg_last50=-200.00
# Episode 62, return=-200.0, avg_last50=-200.00
# Episode 63, return=-172.0, avg_last50=-199.44
# Episode 64, return=-200.0, avg_last50=-199.44
# Episode 65, return=-200.0, avg_last50=-199.44
# Episode 66, return=-200.0, avg_last50=-199.44
# Episode 67, return=-200.0, avg_last50=-199.44
# Episode 68, return=-200.0, avg_last50=-199.44
# Episode 69, return=-200.0, avg_last50=-199.44
# Episode 70, return=-200.0, avg_last50=-199.44
# Episode 71, return=-200.0, avg_last50=-199.44
# Episode 72, return=-200.0, avg_last50=-199.44
# Episode 73, return=-200.0, avg_last50=-199.44
# Episode 74, return=-200.0, avg_last50=-199.44
# Episode 75, return=-172.0, avg_last50=-198.88
# Episode 76, return=-200.0, avg_last50=-198.88
# Episode 77, return=-200.0, avg_last50=-198.88
# Episode 78, return=-200.0, avg_last50=-198.88
# Episode 79, return=-200.0, avg_last50=-198.88
# Episode 80, return=-200.0, avg_last50=-198.88
# Episode 81, return=-200.0, avg_last50=-198.88
# Episode 82, return=-200.0, avg_last50=-198.88
# Episode 83, return=-200.0, avg_last50=-198.88
# Episode 84, return=-200.0, avg_last50=-198.88
# Episode 85, return=-200.0, avg_last50=-198.88
# Episode 86, return=-200.0, avg_last50=-198.88
# Episode 87, return=-200.0, avg_last50=-198.88
# Episode 88, return=-200.0, avg_last50=-198.88
# Episode 89, return=-200.0, avg_last50=-198.88
# Episode 90, return=-200.0, avg_last50=-198.88
# Episode 91, return=-200.0, avg_last50=-198.88
# Episode 92, return=-185.0, avg_last50=-198.58
# Episode 93, return=-200.0, avg_last50=-198.58
# Episode 94, return=-200.0, avg_last50=-198.58
# Episode 95, return=-200.0, avg_last50=-198.58
# Episode 96, return=-169.0, avg_last50=-197.96
# Episode 97, return=-200.0, avg_last50=-197.96
# Episode 98, return=-197.0, avg_last50=-197.90
# Episode 99, return=-174.0, avg_last50=-197.38
# Episode 100, return=-200.0, avg_last50=-197.38
# Episode 101, return=-200.0, avg_last50=-197.38
# Episode 102, return=-200.0, avg_last50=-197.38
# Episode 103, return=-200.0, avg_last50=-197.38
# Episode 104, return=-200.0, avg_last50=-197.38
# Episode 105, return=-200.0, avg_last50=-197.38
# Episode 106, return=-200.0, avg_last50=-197.38
# Episode 107, return=-196.0, avg_last50=-197.30
# Episode 108, return=-166.0, avg_last50=-196.62
# Episode 109, return=-200.0, avg_last50=-196.62
# Episode 110, return=-200.0, avg_last50=-196.62
# Episode 111, return=-200.0, avg_last50=-196.62
# Episode 112, return=-182.0, avg_last50=-196.26
# Episode 113, return=-200.0, avg_last50=-196.82
# Episode 114, return=-169.0, avg_last50=-196.20
# Episode 115, return=-200.0, avg_last50=-196.20
# Episode 116, return=-157.0, avg_last50=-195.34
# Episode 117, return=-153.0, avg_last50=-194.40
# Episode 118, return=-200.0, avg_last50=-194.40
# Episode 119, return=-200.0, avg_last50=-194.40
# Episode 120, return=-200.0, avg_last50=-194.40
# Episode 121, return=-200.0, avg_last50=-194.40
# Episode 122, return=-200.0, avg_last50=-194.40
# Episode 123, return=-166.0, avg_last50=-193.72
# Episode 124, return=-200.0, avg_last50=-193.72
# Episode 125, return=-200.0, avg_last50=-194.28
# Episode 126, return=-168.0, avg_last50=-193.64
# Episode 127, return=-200.0, avg_last50=-193.64
# Episode 128, return=-163.0, avg_last50=-192.90
# Episode 129, return=-200.0, avg_last50=-192.90
# Episode 130, return=-200.0, avg_last50=-192.90
# Episode 131, return=-192.0, avg_last50=-192.74
# Episode 132, return=-158.0, avg_last50=-191.90
# Episode 133, return=-168.0, avg_last50=-191.26
# Episode 134, return=-200.0, avg_last50=-191.26
# Episode 135, return=-200.0, avg_last50=-191.26
# Episode 136, return=-200.0, avg_last50=-191.26
# Episode 137, return=-200.0, avg_last50=-191.26
# Episode 138, return=-200.0, avg_last50=-191.26
# Episode 139, return=-200.0, avg_last50=-191.26
# Episode 140, return=-199.0, avg_last50=-191.24
# Episode 141, return=-200.0, avg_last50=-191.24
# Episode 142, return=-166.0, avg_last50=-190.86
# Episode 143, return=-169.0, avg_last50=-190.24
# Episode 144, return=-200.0, avg_last50=-190.24
# Episode 145, return=-200.0, avg_last50=-190.24
# Episode 146, return=-200.0, avg_last50=-190.86
# Episode 147, return=-196.0, avg_last50=-190.78
# Episode 148, return=-200.0, avg_last50=-190.84
# Episode 149, return=-162.0, avg_last50=-190.60
# Episode 150, return=-152.0, avg_last50=-189.64
# Episode 151, return=-163.0, avg_last50=-188.90
# Episode 152, return=-200.0, avg_last50=-188.90
# Episode 153, return=-200.0, avg_last50=-188.90
# Episode 154, return=-134.0, avg_last50=-187.58
# Episode 155, return=-200.0, avg_last50=-187.58
# Episode 156, return=-200.0, avg_last50=-187.58
# Episode 157, return=-200.0, avg_last50=-187.66
# Episode 158, return=-173.0, avg_last50=-187.80
# Episode 159, return=-184.0, avg_last50=-187.48
# Episode 160, return=-200.0, avg_last50=-187.48
# Episode 161, return=-169.0, avg_last50=-186.86
# Episode 162, return=-193.0, avg_last50=-187.08
# Episode 163, return=-195.0, avg_last50=-186.98
# Episode 164, return=-156.0, avg_last50=-186.72
# Episode 165, return=-200.0, avg_last50=-186.72
# Episode 166, return=-200.0, avg_last50=-187.58
# Episode 167, return=-200.0, avg_last50=-188.52
# Episode 168, return=-163.0, avg_last50=-187.78
# Episode 169, return=-164.0, avg_last50=-187.06
# Episode 170, return=-160.0, avg_last50=-186.26
# Episode 171, return=-200.0, avg_last50=-186.26
# Episode 172, return=-198.0, avg_last50=-186.22
# Episode 173, return=-200.0, avg_last50=-186.90
# Episode 174, return=-161.0, avg_last50=-186.12
# Episode 175, return=-200.0, avg_last50=-186.12
# Episode 176, return=-149.0, avg_last50=-185.74
# Episode 177, return=-164.0, avg_last50=-185.02
# Episode 178, return=-153.0, avg_last50=-184.82
# Episode 179, return=-157.0, avg_last50=-183.96
# Episode 180, return=-200.0, avg_last50=-183.96
# Episode 181, return=-175.0, avg_last50=-183.62
# Episode 182, return=-187.0, avg_last50=-184.20
# Episode 183, return=-163.0, avg_last50=-184.10
# Episode 184, return=-164.0, avg_last50=-183.38
# Episode 185, return=-161.0, avg_last50=-182.60
# Episode 186, return=-157.0, avg_last50=-181.74
# Episode 187, return=-197.0, avg_last50=-181.68
# Episode 188, return=-163.0, avg_last50=-180.94
# Episode 189, return=-160.0, avg_last50=-180.14
# Episode 190, return=-200.0, avg_last50=-180.16
# Episode 191, return=-200.0, avg_last50=-180.16
# Episode 192, return=-175.0, avg_last50=-180.34
# Episode 193, return=-200.0, avg_last50=-180.96
# Episode 194, return=-200.0, avg_last50=-180.96
# Episode 195, return=-200.0, avg_last50=-180.96
# Episode 196, return=-198.0, avg_last50=-180.92
# Episode 197, return=-200.0, avg_last50=-181.00
# Episode 198, return=-120.0, avg_last50=-179.40
# Episode 199, return=-161.0, avg_last50=-179.38
# Episode 200, return=-158.0, avg_last50=-179.50
# Episode 201, return=-200.0, avg_last50=-180.24
# Episode 202, return=-126.0, avg_last50=-178.76
# Episode 203, return=-160.0, avg_last50=-177.96
# Episode 204, return=-162.0, avg_last50=-178.52
# Episode 205, return=-119.0, avg_last50=-176.90
# Episode 206, return=-200.0, avg_last50=-176.90
# Episode 207, return=-170.0, avg_last50=-176.30
# Episode 208, return=-161.0, avg_last50=-176.06
# Episode 209, return=-154.0, avg_last50=-175.46
# Episode 210, return=-159.0, avg_last50=-174.64
# Episode 211, return=-160.0, avg_last50=-174.46
# Episode 212, return=-160.0, avg_last50=-173.80
# Episode 213, return=-200.0, avg_last50=-173.90
# Episode 214, return=-119.0, avg_last50=-173.16
# Episode 215, return=-154.0, avg_last50=-172.24
# Episode 216, return=-147.0, avg_last50=-171.18
# Episode 217, return=-153.0, avg_last50=-170.24
# Episode 218, return=-124.0, avg_last50=-169.46
# Episode 219, return=-164.0, avg_last50=-169.46
# Episode 220, return=-159.0, avg_last50=-169.44
# Episode 221, return=-151.0, avg_last50=-168.46
# Episode 222, return=-115.0, avg_last50=-166.80
# Episode 223, return=-195.0, avg_last50=-166.70
# Episode 224, return=-161.0, avg_last50=-166.70
# Episode 225, return=-153.0, avg_last50=-165.76
# Episode 226, return=-148.0, avg_last50=-165.74
# Episode 227, return=-130.0, avg_last50=-165.06
# Episode 228, return=-168.0, avg_last50=-165.36
# Episode 229, return=-200.0, avg_last50=-166.22
# Episode 230, return=-158.0, avg_last50=-165.38
# Episode 231, return=-155.0, avg_last50=-164.98
# Episode 232, return=-121.0, avg_last50=-163.66
# Episode 233, return=-190.0, avg_last50=-164.20
# Episode 234, return=-151.0, avg_last50=-163.94
# Episode 235, return=-126.0, avg_last50=-163.24
# Episode 236, return=-166.0, avg_last50=-163.42
# Episode 237, return=-153.0, avg_last50=-162.54
# Episode 238, return=-143.0, avg_last50=-162.14
# Episode 239, return=-158.0, avg_last50=-162.10
# Episode 240, return=-161.0, avg_last50=-161.32
# Episode 241, return=-185.0, avg_last50=-161.02
# Episode 242, return=-157.0, avg_last50=-160.66
# Episode 243, return=-165.0, avg_last50=-159.96
# Episode 244, return=-200.0, avg_last50=-159.96
# Episode 245, return=-154.0, avg_last50=-159.04
# Episode 246, return=-161.0, avg_last50=-158.30
# Episode 247, return=-197.0, avg_last50=-158.24
# Episode 248, return=-173.0, avg_last50=-159.30
# Episode 249, return=-147.0, avg_last50=-159.02
# Episode 250, return=-150.0, avg_last50=-158.86
# Episode 251, return=-157.0, avg_last50=-158.00
# Episode 252, return=-129.0, avg_last50=-158.06
# Episode 253, return=-160.0, avg_last50=-158.06
# Episode 254, return=-117.0, avg_last50=-157.16
# Episode 255, return=-160.0, avg_last50=-157.98
# Episode 256, return=-185.0, avg_last50=-157.68
# Episode 257, return=-132.0, avg_last50=-156.92
# Episode 258, return=-114.0, avg_last50=-155.98
# Episode 259, return=-159.0, avg_last50=-156.08
# Episode 260, return=-154.0, avg_last50=-155.98
# Episode 261, return=-155.0, avg_last50=-155.88
# Episode 262, return=-162.0, avg_last50=-155.92
# Episode 263, return=-162.0, avg_last50=-155.16
# Episode 264, return=-155.0, avg_last50=-155.88
# Episode 265, return=-153.0, avg_last50=-155.86
# Episode 266, return=-152.0, avg_last50=-155.96
# Episode 267, return=-162.0, avg_last50=-156.14
# Episode 268, return=-151.0, avg_last50=-156.68
# Episode 269, return=-153.0, avg_last50=-156.46
# Episode 270, return=-161.0, avg_last50=-156.50
# Episode 271, return=-153.0, avg_last50=-156.54
# Episode 272, return=-134.0, avg_last50=-156.92
# Episode 273, return=-189.0, avg_last50=-156.80
# Episode 274, return=-194.0, avg_last50=-157.46
# Episode 275, return=-183.0, avg_last50=-158.06
# Episode 276, return=-115.0, avg_last50=-157.40
# Episode 277, return=-172.0, avg_last50=-158.24
# Episode 278, return=-142.0, avg_last50=-157.72
# Episode 279, return=-156.0, avg_last50=-156.84
# Episode 280, return=-193.0, avg_last50=-157.54
# Episode 281, return=-200.0, avg_last50=-158.44
# Episode 282, return=-119.0, avg_last50=-158.40
# Episode 283, return=-132.0, avg_last50=-157.24
# Episode 284, return=-127.0, avg_last50=-156.76
# Episode 285, return=-168.0, avg_last50=-157.60
# Episode 286, return=-200.0, avg_last50=-158.28
# Episode 287, return=-161.0, avg_last50=-158.44
# Episode 288, return=-147.0, avg_last50=-158.52
# Episode 289, return=-146.0, avg_last50=-158.28
# Episode 290, return=-155.0, avg_last50=-158.16
# Episode 291, return=-122.0, avg_last50=-156.90
# Episode 292, return=-116.0, avg_last50=-156.08
# Episode 293, return=-117.0, avg_last50=-155.12
# Episode 294, return=-117.0, avg_last50=-153.46
# Episode 295, return=-125.0, avg_last50=-152.88
# Episode 296, return=-178.0, avg_last50=-153.22
# Episode 297, return=-125.0, avg_last50=-151.78
# Episode 298, return=-113.0, avg_last50=-150.58
# Episode 299, return=-115.0, avg_last50=-149.94
# Episode 300, return=-124.0, avg_last50=-149.42
# Episode 301, return=-122.0, avg_last50=-148.72
# Episode 302, return=-120.0, avg_last50=-148.54
# Episode 303, return=-162.0, avg_last50=-148.58
# Episode 304, return=-174.0, avg_last50=-149.72
# Episode 305, return=-127.0, avg_last50=-149.06
# Episode 306, return=-116.0, avg_last50=-147.68
# Episode 307, return=-170.0, avg_last50=-148.44
# Episode 308, return=-121.0, avg_last50=-148.58
# Episode 309, return=-160.0, avg_last50=-148.60
# Episode 310, return=-160.0, avg_last50=-148.72
# Episode 311, return=-147.0, avg_last50=-148.56
# Episode 312, return=-118.0, avg_last50=-147.68
# Episode 313, return=-164.0, avg_last50=-147.72
# Episode 314, return=-126.0, avg_last50=-147.14
# Episode 315, return=-122.0, avg_last50=-146.52
# Episode 316, return=-121.0, avg_last50=-145.90
# Episode 317, return=-154.0, avg_last50=-145.74
# Episode 318, return=-113.0, avg_last50=-144.98
# Episode 319, return=-161.0, avg_last50=-145.14
# Episode 320, return=-151.0, avg_last50=-144.94
# Episode 321, return=-126.0, avg_last50=-144.40
# Episode 322, return=-146.0, avg_last50=-144.64
# Episode 323, return=-118.0, avg_last50=-143.22
# Episode 324, return=-176.0, avg_last50=-142.86
# Episode 325, return=-115.0, avg_last50=-141.50
# Episode 326, return=-114.0, avg_last50=-141.48
# Episode 327, return=-122.0, avg_last50=-140.48
# Episode 328, return=-116.0, avg_last50=-139.96
# Episode 329, return=-114.0, avg_last50=-139.12
# Episode 330, return=-152.0, avg_last50=-138.30
# Episode 331, return=-114.0, avg_last50=-136.58
# Episode 332, return=-115.0, avg_last50=-136.50
# Episode 333, return=-117.0, avg_last50=-136.20
# Episode 334, return=-146.0, avg_last50=-136.58
# Episode 335, return=-121.0, avg_last50=-135.64
# Episode 336, return=-157.0, avg_last50=-134.78
# Episode 337, return=-113.0, avg_last50=-133.82
# Episode 338, return=-152.0, avg_last50=-133.92
# Episode 339, return=-151.0, avg_last50=-134.02
# Episode 340, return=-154.0, avg_last50=-134.00
# Episode 341, return=-158.0, avg_last50=-134.72
# Episode 342, return=-133.0, avg_last50=-135.06
# Episode 343, return=-192.0, avg_last50=-136.56
# Episode 344, return=-150.0, avg_last50=-137.22
# Episode 345, return=-151.0, avg_last50=-137.74
# Episode 346, return=-200.0, avg_last50=-138.18
# Episode 347, return=-183.0, avg_last50=-139.34
# Episode 348, return=-119.0, avg_last50=-139.46
# Episode 349, return=-162.0, avg_last50=-140.40
# Episode 350, return=-112.0, avg_last50=-140.16
# Episode 351, return=-150.0, avg_last50=-140.72
# Episode 352, return=-157.0, avg_last50=-141.46
# Episode 353, return=-157.0, avg_last50=-141.36
# Episode 354, return=-148.0, avg_last50=-140.84
# Episode 355, return=-156.0, avg_last50=-141.42
# Episode 356, return=-133.0, avg_last50=-141.76
# Episode 357, return=-200.0, avg_last50=-142.36
# Episode 358, return=-153.0, avg_last50=-143.00
# Episode 359, return=-152.0, avg_last50=-142.84
# Episode 360, return=-153.0, avg_last50=-142.70
# Episode 361, return=-149.0, avg_last50=-142.74
# Episode 362, return=-135.0, avg_last50=-143.08
# Episode 363, return=-121.0, avg_last50=-142.22
# Episode 364, return=-152.0, avg_last50=-142.74
# Episode 365, return=-153.0, avg_last50=-143.36
# Episode 366, return=-150.0, avg_last50=-143.94
# Episode 367, return=-154.0, avg_last50=-143.94
# Episode 368, return=-119.0, avg_last50=-144.06
# Episode 369, return=-114.0, avg_last50=-143.12
# Episode 370, return=-114.0, avg_last50=-142.38
# Episode 371, return=-152.0, avg_last50=-142.90
# Episode 372, return=-122.0, avg_last50=-142.42
# Episode 373, return=-161.0, avg_last50=-143.28
# Episode 374, return=-120.0, avg_last50=-142.16
# Episode 375, return=-149.0, avg_last50=-142.84
# Episode 376, return=-148.0, avg_last50=-143.52
# Episode 377, return=-145.0, avg_last50=-143.98
# Episode 378, return=-124.0, avg_last50=-144.14
# Episode 379, return=-124.0, avg_last50=-144.34
# Episode 380, return=-123.0, avg_last50=-143.76
# Episode 381, return=-156.0, avg_last50=-144.60
# Episode 382, return=-114.0, avg_last50=-144.58
# Episode 383, return=-147.0, avg_last50=-145.18
# Episode 384, return=-150.0, avg_last50=-145.26
# Episode 385, return=-152.0, avg_last50=-145.88
# Episode 386, return=-151.0, avg_last50=-145.76
# Episode 387, return=-148.0, avg_last50=-146.46
# Episode 388, return=-149.0, avg_last50=-146.40
# Episode 389, return=-154.0, avg_last50=-146.46
# Episode 390, return=-158.0, avg_last50=-146.54
# Episode 391, return=-141.0, avg_last50=-146.20
# Episode 392, return=-153.0, avg_last50=-146.60
# Episode 393, return=-160.0, avg_last50=-145.96
# Episode 394, return=-157.0, avg_last50=-146.10
# Episode 395, return=-152.0, avg_last50=-146.12
# Episode 396, return=-154.0, avg_last50=-145.20
# Episode 397, return=-153.0, avg_last50=-144.60
# Episode 398, return=-153.0, avg_last50=-145.28
# Episode 399, return=-146.0, avg_last50=-144.96
# Episode 400, return=-148.0, avg_last50=-145.68
# Episode 401, return=-152.0, avg_last50=-145.72
# Episode 402, return=-148.0, avg_last50=-145.54
# Episode 403, return=-91.0, avg_last50=-144.22
# Episode 404, return=-113.0, avg_last50=-143.52
# Episode 405, return=-160.0, avg_last50=-143.60
# Episode 406, return=-187.0, avg_last50=-144.68
# Episode 407, return=-153.0, avg_last50=-143.74
# Episode 408, return=-118.0, avg_last50=-143.04
# Episode 409, return=-149.0, avg_last50=-142.98
# Episode 410, return=-151.0, avg_last50=-142.94
# Episode 411, return=-125.0, avg_last50=-142.46
# Episode 412, return=-154.0, avg_last50=-142.84
# Episode 413, return=-144.0, avg_last50=-143.30
# Episode 414, return=-151.0, avg_last50=-143.28
# Episode 415, return=-148.0, avg_last50=-143.18
# Episode 416, return=-148.0, avg_last50=-143.14
# Episode 417, return=-145.0, avg_last50=-142.96
# Episode 418, return=-149.0, avg_last50=-143.56
# Episode 419, return=-146.0, avg_last50=-144.20
# Episode 420, return=-146.0, avg_last50=-144.84
# Episode 421, return=-139.0, avg_last50=-144.58
# Episode 422, return=-164.0, avg_last50=-145.42
# Episode 423, return=-120.0, avg_last50=-144.60
# Episode 424, return=-158.0, avg_last50=-145.36
# Episode 425, return=-141.0, avg_last50=-145.20
# Episode 426, return=-158.0, avg_last50=-145.40
# Episode 427, return=-146.0, avg_last50=-145.42
# Episode 428, return=-143.0, avg_last50=-145.80
# Episode 429, return=-155.0, avg_last50=-146.42
# Episode 430, return=-131.0, avg_last50=-146.58
# Episode 431, return=-112.0, avg_last50=-145.70
# Episode 432, return=-149.0, avg_last50=-146.40
# Episode 433, return=-116.0, avg_last50=-145.78
# Episode 434, return=-117.0, avg_last50=-145.12
# Episode 435, return=-153.0, avg_last50=-145.14
# Episode 436, return=-160.0, avg_last50=-145.32
# Episode 437, return=-163.0, avg_last50=-145.62
# Episode 438, return=-153.0, avg_last50=-145.70
# Episode 439, return=-144.0, avg_last50=-145.50
# Episode 440, return=-156.0, avg_last50=-145.46
# Episode 441, return=-151.0, avg_last50=-145.66
# Episode 442, return=-154.0, avg_last50=-145.68
# Episode 443, return=-154.0, avg_last50=-145.56
# Episode 444, return=-148.0, avg_last50=-145.38
# Episode 445, return=-155.0, avg_last50=-145.44
# Episode 446, return=-153.0, avg_last50=-145.42
# Episode 447, return=-125.0, avg_last50=-144.86
# Episode 448, return=-123.0, avg_last50=-144.26
# Episode 449, return=-118.0, avg_last50=-143.70
# Episode 450, return=-148.0, avg_last50=-143.70
# Episode 451, return=-157.0, avg_last50=-143.80
# Episode 452, return=-149.0, avg_last50=-143.82
# Episode 453, return=-154.0, avg_last50=-145.08
# Episode 454, return=-91.0, avg_last50=-144.64
# Episode 455, return=-151.0, avg_last50=-144.46
# Episode 456, return=-126.0, avg_last50=-143.24
# Episode 457, return=-153.0, avg_last50=-143.24
# Episode 458, return=-119.0, avg_last50=-143.26
# Episode 459, return=-154.0, avg_last50=-143.36
# Episode 460, return=-127.0, avg_last50=-142.88
# Episode 461, return=-149.0, avg_last50=-143.36
# Episode 462, return=-146.0, avg_last50=-143.20
# Episode 463, return=-163.0, avg_last50=-143.58
# Episode 464, return=-156.0, avg_last50=-143.68
# Episode 465, return=-146.0, avg_last50=-143.64
# Episode 466, return=-119.0, avg_last50=-143.06
# Episode 467, return=-117.0, avg_last50=-142.50
# Episode 468, return=-150.0, avg_last50=-142.52
# Episode 469, return=-117.0, avg_last50=-141.94
# Episode 470, return=-151.0, avg_last50=-142.04
# Episode 471, return=-155.0, avg_last50=-142.36
# Episode 472, return=-153.0, avg_last50=-142.14
# Episode 473, return=-146.0, avg_last50=-142.66
# Episode 474, return=-142.0, avg_last50=-142.34
# Episode 475, return=-149.0, avg_last50=-142.50
# Episode 476, return=-141.0, avg_last50=-142.16
# Episode 477, return=-117.0, avg_last50=-141.58
# Episode 478, return=-153.0, avg_last50=-141.78
# Episode 479, return=-147.0, avg_last50=-141.62
# Episode 480, return=-150.0, avg_last50=-142.00
# Episode 481, return=-152.0, avg_last50=-142.80
# Episode 482, return=-144.0, avg_last50=-142.70
# Episode 483, return=-146.0, avg_last50=-143.30
# Episode 484, return=-146.0, avg_last50=-143.88
# Episode 485, return=-143.0, avg_last50=-143.68
# Episode 486, return=-150.0, avg_last50=-143.48
# Episode 487, return=-156.0, avg_last50=-143.34
# Episode 488, return=-145.0, avg_last50=-143.18
# Episode 489, return=-146.0, avg_last50=-143.22
# Episode 490, return=-162.0, avg_last50=-143.34
# Episode 491, return=-141.0, avg_last50=-143.14
# Episode 492, return=-149.0, avg_last50=-143.04
# Episode 493, return=-149.0, avg_last50=-142.94
# Episode 494, return=-125.0, avg_last50=-142.48
# Episode 495, return=-155.0, avg_last50=-142.48
# Episode 496, return=-152.0, avg_last50=-142.46
# Episode 497, return=-156.0, avg_last50=-143.08
# Episode 498, return=-149.0, avg_last50=-143.60
# Episode 499, return=-149.0, avg_last50=-144.22
# Episode 500, return=-130.0, avg_last50=-143.86

# %% [markdown]
# It would appear when playing with the number of tilinings that the more you add the better results you get...but at a high computational cost(takes longer). But with too few tilings it takes too long for it to learn too.  For the tiles per dimension (aka resultion), the higher you make the resultion the better the algorithm is at partitioning the state, in this case this would represent the slope of the car on the hill as it chnages, so we need a large enough dimention to represent this.  With a Lower resolution i would not represent the changing slope well.
